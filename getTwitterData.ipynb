# %% [markdown]
# # Twitter - Historical Data Extraction

# %% [markdown]
#
# 1. Get Python >= 3.8.0
# 2. Install:
#
# ```$:> pip install git+https://github.com/JustAnotherArchivist/snscrape.git```
#
# ```$:> pip install snscrape```
#
# 3. Set: `start_date` = "YYYY-MM-DD", `end_date` = "YYYY-MM-DD"
# 4. Run  `get_tweets()`
# 5. Save output df in a CSV format.

# %% [markdown]
# ## Imports

# %%
import os
import time
from ast import literal_eval
from datetime import datetime
import pandas as pd
import snscrape.modules.twitter as sntwitter # the magic
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Directory Setup

# %%
root_dir = os.path.abspath(os.path.join(os.path.dirname("."), '.'))

# %% [markdown]
# ## Extractor Module

# %%
class ExtractTweets:
    
    def __init__(self, 
                 minTweetCountPerDay=10, 
                 minRetweetCount=0,
                 minLikeCount=0, 
                 minFollowersCount=0, 
                 VerifiedStatus=None, 
                 saveBufferDuration=3600):
        """
        Accepts basic input params each of integer datatype, except for VerifiedStatus which accepts boolean or None.
        """
        self.start_timer = datetime.strptime(time.strftime("%Y-%m-%d %H:%M:%S"), "%Y-%m-%d %H:%M:%S")
        self.min_tweet_count_perDay = minTweetCountPerDay
        self.minRetweetCount = minRetweetCount
        self.minLikeCount = minLikeCount
        self.minFollowersCount = minFollowersCount
        self.VerifiedStatus = VerifiedStatus                           
        self.tweets_df = pd.DataFrame(columns=['date', 'tweet', 'lang', 'retweetCount', 'likeCount', 'replyCount', 
                                               'username', 'user_followersCount','user_friendsCount', 'verifiedStatus', 
                                               'tweet_url', 'hastags', 'chr_count', 'topic'])
        self.save_buffer_duration = saveBufferDuration
        return

    def save_copy(self):
        """
        Saves a temp copy for restoration and prevent API time limit exceed error.
        
        :return:
        pandas dataframe containing twitter record-data.
        """
        data = self.tweets_df.reset_index(drop=True)
        data['date'] = data['date'].apply(lambda x: pd.to_datetime(x).strftime('%Y-%m-%d'))
        for filename in os.listdir("."):
            if filename.endswith('local.csv'):
                os.remove(filename)
        data.to_csv("./save_{}_local.csv".format(data.date.max()), index=False)
        return data
        
    def getTweets(self, start_date, end_date, keywords):
        """
        Extracts historical twitter data.
        
        :params:
        start_date - str in "YYYY-MM-DD" format
        end_date - str in "YYYY-MM-DD" format
        keywords - list of tuples, 
            e.g, [('recession'), ('football, 'worldcup', 'fifa'), ('war', 'ukraine')]
            e.g. ['recession']
        
        :return:
        pandas dataframe with features as:
         date: Tweet Timestamp
         tweet: tweet content
         lang: language classifer used by parent api
         retweetCount: tweet retweeted count
         likeCount: tweet like count
         replyCount: number of replies to original tweet
         username: user who tweeted
         user_followersCount: number of followers user has (tells you how popular the avg tweets are)
         user_friendsCount: number of friends user has
         verifiedStatus: If the user is Verified or not (i.e. pays 8 bucks every month!)
         tweet_url: Link of original tweet (click and see)
         hastags: If any hastags were used (hastags are important for search and info retrieval)
         chr_count: number of english characters in the original tweet
         topic: keywords you used for searching tweets (kind of labels)
        """
        
        if not(isinstance(keywords, list) or isinstance(keywords, tuple)):
            raise Exception("Incorrect Input Format! Please pass a list")
        
        for topic in keywords:
            # for saving local copies every buffer_hour
            st_time = datetime.strptime(time.strftime("%Y-%m-%d %H:%M:%S"), "%Y-%m-%d %H:%M:%S")
            date = pd.to_datetime(start_date, format='%Y-%m-%d')
            e_date = pd.to_datetime(end_date, format='%Y-%m-%d') + pd.to_timedelta(1, unit='d')
            if isinstance(topic, tuple) or isinstance(topic, list):
                topic = " ".join(topic)
            search_query = topic
            print("search_query:", search_query)
        
            while date != e_date:
                nxt_date = date + pd.to_timedelta(1, unit='d')
                content = '{} since:{} until:{}'.format(search_query, date.strftime('%Y-%m-%d'), nxt_date.strftime('%Y-%m-%d'))
                print(content)
                
                # check for save buffer duration (set to 1 Hr by default)
                delta_buffer = (datetime.strptime(time.strftime("%Y-%m-%d %H:%M:%S"), "%Y-%m-%d %H:%M:%S") - st_time).seconds
                if delta_buffer >= self.save_buffer_duration:
                    self.save_copy()
                    # reset buffer
                    st_time = datetime.strptime(time.strftime("%Y-%m-%d %H:%M:%S"), "%Y-%m-%d %H:%M:%S")

                lst_tweets = []
                for counter, tweet in enumerate(sntwitter.TwitterSearchScraper(content).get_items()):
                    if counter+1 > self.min_tweet_count_perDay: 
                        break
                    if tweet.likeCount >= self.minLikeCount \
                        or tweet.retweetCount >= self.minRetweetCount \
                        or tweet.user.followersCount >= self.minFollowersCount \
                        or (tweet.user.verified and isinstance(tweet.user.verified, bool) and tweet.user.verified == self.VerifiedStatus):
                        
                        # ----------------------------------------------------------------
                        # Potential custom preprocessing module here: 
                        # 1. Simple and short: https://www.kaggle.com/code/zenbird01/pranjalpathak-semantic-clustering-v1-0/notebook
                        # 2. Advanced: ./NLP_basics_preprocessing_vectorization_similarity.ipynb
                        # 3. Best: Check github - https://github.com/pranzell/NLP_Tools
                        # ----------------------------------------------------------------
                        
                        lst_tweets.append([
                            topic,
                            tweet.date, 
                            tweet.content, 
                            tweet.lang,
                            tweet.retweetCount,
                            tweet.likeCount,
                            tweet.replyCount,
                            tweet.user.username, 
                            tweet.user.followersCount, 
                            tweet.user.friendsCount, 
                            tweet.user.verified,
                            tweet.url,
                            tweet.hashtags,
                            len(str(tweet.content).strip()),
                            topic])
                
                self.tweets_df = self.tweets_df.append(pd.DataFrame(lst_tweets, columns=self.tweets_df.columns))
                date = nxt_date
        
        print("\n\nTOTAL TIME TAKEN {} minutes".format(((datetime.strptime(time.strftime("%Y-%m-%d %H:%M:%S"), "%Y-%m-%d %H:%M:%S") - self.start_timer).seconds)/60.0))
        return self.save_copy()
    
    
    def preprocess_shortText(self, text_col):
        # refer to Preprocessing ipynb file
        # https://github.com/pranzell/NLP_Tools
        pass

# %% [markdown]
# ## <ins>Execute</ins>

# %% [markdown]
# ### Configuration

# %%
minTweetCountPerDay=50
minRetweetCount=100
minLikeCount=100
minFollowersCount=200
VerifiedStatus=None
saveBufferDuration=3600 # in seconds

start_date = "2022-04-01"
end_date = "2022-12-01"

# list of tuples, or a list of single str items check function definition `getTweets()`
keywords = [('russia ukrain war'),('inflation'),('gas prices')]

# %% [markdown]
# ### Run

# %%
et = ExtractTweets(minTweetCountPerDay, minRetweetCount, minLikeCount, minFollowersCount, VerifiedStatus, saveBufferDuration)
twitter_data = et.getTweets(start_date, end_date, keywords)
# Out:
# search_query: russia ukrain war
# russia ukrain war since:2022-04-01 until:2022-04-02
# russia ukrain war since:2022-04-02 until:2022-04-03
# russia ukrain war since:2022-04-03 until:2022-04-04
# russia ukrain war since:2022-04-04 until:2022-04-05
# russia ukrain war since:2022-04-05 until:2022-04-06
# russia ukrain war since:2022-04-06 until:2022-04-07
# russia ukrain war since:2022-04-07 until:2022-04-08
# russia ukrain war since:2022-04-08 until:2022-04-09
# russia ukrain war since:2022-04-09 until:2022-04-10
# russia ukrain war since:2022-04-10 until:2022-04-11
# russia ukrain war since:2022-04-11 until:2022-04-12
# russia ukrain war since:2022-04-12 until:2022-04-13
# russia ukrain war since:2022-04-13 until:2022-04-14
# russia ukrain war since:2022-04-14 until:2022-04-15
# russia ukrain war since:2022-04-15 until:2022-04-16
# russia ukrain war since:2022-04-16 until:2022-04-17
# russia ukrain war since:2022-04-17 until:2022-04-18
# russia ukrain war since:2022-04-18 until:2022-04-19
# russia ukrain war since:2022-04-19 until:2022-04-20
# russia ukrain war since:2022-04-20 until:2022-04-21
# russia ukrain war since:2022-04-21 until:2022-04-22
# russia ukrain war since:2022-04-22 until:2022-04-23
# russia ukrain war since:2022-04-23 until:2022-04-24
# russia ukrain war since:2022-04-24 until:2022-04-25
# russia ukrain war since:2022-04-25 until:2022-04-26
# russia ukrain war since:2022-04-26 until:2022-04-27
# russia ukrain war since:2022-04-27 until:2022-04-28
# russia ukrain war since:2022-04-28 until:2022-04-29
# russia ukrain war since:2022-04-29 until:2022-04-30
# russia ukrain war since:2022-04-30 until:2022-05-01
# russia ukrain war since:2022-05-01 until:2022-05-02
# russia ukrain war since:2022-05-02 until:2022-05-03
# russia ukrain war since:2022-05-03 until:2022-05-04
# russia ukrain war since:2022-05-04 until:2022-05-05
# russia ukrain war since:2022-05-05 until:2022-05-06
# russia ukrain war since:2022-05-06 until:2022-05-07
# russia ukrain war since:2022-05-07 until:2022-05-08
# russia ukrain war since:2022-05-08 until:2022-05-09
# russia ukrain war since:2022-05-09 until:2022-05-10
# russia ukrain war since:2022-05-10 until:2022-05-11
# russia ukrain war since:2022-05-11 until:2022-05-12
# russia ukrain war since:2022-05-12 until:2022-05-13
# russia ukrain war since:2022-05-13 until:2022-05-14
# russia ukrain war since:2022-05-14 until:2022-05-15
# russia ukrain war since:2022-05-15 until:2022-05-16
# russia ukrain war since:2022-05-16 until:2022-05-17
# russia ukrain war since:2022-05-17 until:2022-05-18
# russia ukrain war since:2022-05-18 until:2022-05-19
# russia ukrain war since:2022-05-19 until:2022-05-20
# russia ukrain war since:2022-05-20 until:2022-05-21
# russia ukrain war since:2022-05-21 until:2022-05-22
# russia ukrain war since:2022-05-22 until:2022-05-23
# russia ukrain war since:2022-05-23 until:2022-05-24
# russia ukrain war since:2022-05-24 until:2022-05-25
# russia ukrain war since:2022-05-25 until:2022-05-26
# russia ukrain war since:2022-05-26 until:2022-05-27
# russia ukrain war since:2022-05-27 until:2022-05-28
# russia ukrain war since:2022-05-28 until:2022-05-29
# russia ukrain war since:2022-05-29 until:2022-05-30
# russia ukrain war since:2022-05-30 until:2022-05-31
# russia ukrain war since:2022-05-31 until:2022-06-01
# russia ukrain war since:2022-06-01 until:2022-06-02
# russia ukrain war since:2022-06-02 until:2022-06-03
# russia ukrain war since:2022-06-03 until:2022-06-04
# russia ukrain war since:2022-06-04 until:2022-06-05
# russia ukrain war since:2022-06-05 until:2022-06-06
# russia ukrain war since:2022-06-06 until:2022-06-07
# russia ukrain war since:2022-06-07 until:2022-06-08
# russia ukrain war since:2022-06-08 until:2022-06-09
# russia ukrain war since:2022-06-09 until:2022-06-10
# russia ukrain war since:2022-06-10 until:2022-06-11
# russia ukrain war since:2022-06-11 until:2022-06-12
# russia ukrain war since:2022-06-12 until:2022-06-13
# russia ukrain war since:2022-06-13 until:2022-06-14
# russia ukrain war since:2022-06-14 until:2022-06-15
# russia ukrain war since:2022-06-15 until:2022-06-16
# russia ukrain war since:2022-06-16 until:2022-06-17
# russia ukrain war since:2022-06-17 until:2022-06-18
# russia ukrain war since:2022-06-18 until:2022-06-19
# russia ukrain war since:2022-06-19 until:2022-06-20
# russia ukrain war since:2022-06-20 until:2022-06-21
# russia ukrain war since:2022-06-21 until:2022-06-22
# russia ukrain war since:2022-06-22 until:2022-06-23
# russia ukrain war since:2022-06-23 until:2022-06-24
# russia ukrain war since:2022-06-24 until:2022-06-25
# russia ukrain war since:2022-06-25 until:2022-06-26
# russia ukrain war since:2022-06-26 until:2022-06-27
# russia ukrain war since:2022-06-27 until:2022-06-28
# russia ukrain war since:2022-06-28 until:2022-06-29
# russia ukrain war since:2022-06-29 until:2022-06-30
# russia ukrain war since:2022-06-30 until:2022-07-01
# russia ukrain war since:2022-07-01 until:2022-07-02
# russia ukrain war since:2022-07-02 until:2022-07-03
# russia ukrain war since:2022-07-03 until:2022-07-04
# russia ukrain war since:2022-07-04 until:2022-07-05
# russia ukrain war since:2022-07-05 until:2022-07-06
# russia ukrain war since:2022-07-06 until:2022-07-07
# russia ukrain war since:2022-07-07 until:2022-07-08
# russia ukrain war since:2022-07-08 until:2022-07-09
# russia ukrain war since:2022-07-09 until:2022-07-10
# russia ukrain war since:2022-07-10 until:2022-07-11
# russia ukrain war since:2022-07-11 until:2022-07-12
# russia ukrain war since:2022-07-12 until:2022-07-13
# russia ukrain war since:2022-07-13 until:2022-07-14
# russia ukrain war since:2022-07-14 until:2022-07-15
# russia ukrain war since:2022-07-15 until:2022-07-16
# russia ukrain war since:2022-07-16 until:2022-07-17
# russia ukrain war since:2022-07-17 until:2022-07-18
# russia ukrain war since:2022-07-18 until:2022-07-19
# russia ukrain war since:2022-07-19 until:2022-07-20
# russia ukrain war since:2022-07-20 until:2022-07-21
# russia ukrain war since:2022-07-21 until:2022-07-22
# russia ukrain war since:2022-07-22 until:2022-07-23
# russia ukrain war since:2022-07-23 until:2022-07-24
# russia ukrain war since:2022-07-24 until:2022-07-25
# russia ukrain war since:2022-07-25 until:2022-07-26
# russia ukrain war since:2022-07-26 until:2022-07-27
# russia ukrain war since:2022-07-27 until:2022-07-28
# russia ukrain war since:2022-07-28 until:2022-07-29
# russia ukrain war since:2022-07-29 until:2022-07-30
# russia ukrain war since:2022-07-30 until:2022-07-31
# russia ukrain war since:2022-07-31 until:2022-08-01
# russia ukrain war since:2022-08-01 until:2022-08-02
# russia ukrain war since:2022-08-02 until:2022-08-03
# russia ukrain war since:2022-08-03 until:2022-08-04
# russia ukrain war since:2022-08-04 until:2022-08-05
# russia ukrain war since:2022-08-05 until:2022-08-06
# russia ukrain war since:2022-08-06 until:2022-08-07
# russia ukrain war since:2022-08-07 until:2022-08-08
# russia ukrain war since:2022-08-08 until:2022-08-09
# russia ukrain war since:2022-08-09 until:2022-08-10
# russia ukrain war since:2022-08-10 until:2022-08-11
# russia ukrain war since:2022-08-11 until:2022-08-12
# russia ukrain war since:2022-08-12 until:2022-08-13
# russia ukrain war since:2022-08-13 until:2022-08-14
# russia ukrain war since:2022-08-14 until:2022-08-15
# russia ukrain war since:2022-08-15 until:2022-08-16
# russia ukrain war since:2022-08-16 until:2022-08-17
# russia ukrain war since:2022-08-17 until:2022-08-18
# russia ukrain war since:2022-08-18 until:2022-08-19
# russia ukrain war since:2022-08-19 until:2022-08-20
# russia ukrain war since:2022-08-20 until:2022-08-21
# russia ukrain war since:2022-08-21 until:2022-08-22
# russia ukrain war since:2022-08-22 until:2022-08-23
# russia ukrain war since:2022-08-23 until:2022-08-24
# russia ukrain war since:2022-08-24 until:2022-08-25
# russia ukrain war since:2022-08-25 until:2022-08-26
# russia ukrain war since:2022-08-26 until:2022-08-27
# russia ukrain war since:2022-08-27 until:2022-08-28
# russia ukrain war since:2022-08-28 until:2022-08-29
# russia ukrain war since:2022-08-29 until:2022-08-30
# russia ukrain war since:2022-08-30 until:2022-08-31
# russia ukrain war since:2022-08-31 until:2022-09-01
# russia ukrain war since:2022-09-01 until:2022-09-02
# russia ukrain war since:2022-09-02 until:2022-09-03
# russia ukrain war since:2022-09-03 until:2022-09-04
# russia ukrain war since:2022-09-04 until:2022-09-05
# russia ukrain war since:2022-09-05 until:2022-09-06
# russia ukrain war since:2022-09-06 until:2022-09-07
# russia ukrain war since:2022-09-07 until:2022-09-08
# russia ukrain war since:2022-09-08 until:2022-09-09
# russia ukrain war since:2022-09-09 until:2022-09-10
# russia ukrain war since:2022-09-10 until:2022-09-11
# russia ukrain war since:2022-09-11 until:2022-09-12
# russia ukrain war since:2022-09-12 until:2022-09-13
# russia ukrain war since:2022-09-13 until:2022-09-14
# russia ukrain war since:2022-09-14 until:2022-09-15
# russia ukrain war since:2022-09-15 until:2022-09-16
# russia ukrain war since:2022-09-16 until:2022-09-17
# russia ukrain war since:2022-09-17 until:2022-09-18
# russia ukrain war since:2022-09-18 until:2022-09-19
# russia ukrain war since:2022-09-19 until:2022-09-20
# russia ukrain war since:2022-09-20 until:2022-09-21
# russia ukrain war since:2022-09-21 until:2022-09-22
# russia ukrain war since:2022-09-22 until:2022-09-23
# russia ukrain war since:2022-09-23 until:2022-09-24
# russia ukrain war since:2022-09-24 until:2022-09-25
# russia ukrain war since:2022-09-25 until:2022-09-26
# russia ukrain war since:2022-09-26 until:2022-09-27
# russia ukrain war since:2022-09-27 until:2022-09-28
# russia ukrain war since:2022-09-28 until:2022-09-29
# russia ukrain war since:2022-09-29 until:2022-09-30
# russia ukrain war since:2022-09-30 until:2022-10-01
# russia ukrain war since:2022-10-01 until:2022-10-02
# russia ukrain war since:2022-10-02 until:2022-10-03
# russia ukrain war since:2022-10-03 until:2022-10-04
# russia ukrain war since:2022-10-04 until:2022-10-05
# russia ukrain war since:2022-10-05 until:2022-10-06
# russia ukrain war since:2022-10-06 until:2022-10-07
# russia ukrain war since:2022-10-07 until:2022-10-08
# russia ukrain war since:2022-10-08 until:2022-10-09
# russia ukrain war since:2022-10-09 until:2022-10-10
# russia ukrain war since:2022-10-10 until:2022-10-11
# russia ukrain war since:2022-10-11 until:2022-10-12
# russia ukrain war since:2022-10-12 until:2022-10-13
# russia ukrain war since:2022-10-13 until:2022-10-14
# russia ukrain war since:2022-10-14 until:2022-10-15
# russia ukrain war since:2022-10-15 until:2022-10-16
# russia ukrain war since:2022-10-16 until:2022-10-17
# russia ukrain war since:2022-10-17 until:2022-10-18
# russia ukrain war since:2022-10-18 until:2022-10-19
# russia ukrain war since:2022-10-19 until:2022-10-20
# russia ukrain war since:2022-10-20 until:2022-10-21
# russia ukrain war since:2022-10-21 until:2022-10-22
# russia ukrain war since:2022-10-22 until:2022-10-23
# russia ukrain war since:2022-10-23 until:2022-10-24
# russia ukrain war since:2022-10-24 until:2022-10-25
# russia ukrain war since:2022-10-25 until:2022-10-26
# russia ukrain war since:2022-10-26 until:2022-10-27
# russia ukrain war since:2022-10-27 until:2022-10-28
# russia ukrain war since:2022-10-28 until:2022-10-29
# russia ukrain war since:2022-10-29 until:2022-10-30
# russia ukrain war since:2022-10-30 until:2022-10-31
# russia ukrain war since:2022-10-31 until:2022-11-01
# russia ukrain war since:2022-11-01 until:2022-11-02
# russia ukrain war since:2022-11-02 until:2022-11-03
# russia ukrain war since:2022-11-03 until:2022-11-04
# russia ukrain war since:2022-11-04 until:2022-11-05
# russia ukrain war since:2022-11-05 until:2022-11-06
# russia ukrain war since:2022-11-06 until:2022-11-07
# russia ukrain war since:2022-11-07 until:2022-11-08
# russia ukrain war since:2022-11-08 until:2022-11-09
# russia ukrain war since:2022-11-09 until:2022-11-10
# russia ukrain war since:2022-11-10 until:2022-11-11
# russia ukrain war since:2022-11-11 until:2022-11-12
# russia ukrain war since:2022-11-12 until:2022-11-13
# russia ukrain war since:2022-11-13 until:2022-11-14
# russia ukrain war since:2022-11-14 until:2022-11-15
# russia ukrain war since:2022-11-15 until:2022-11-16
# russia ukrain war since:2022-11-16 until:2022-11-17
# russia ukrain war since:2022-11-17 until:2022-11-18
# russia ukrain war since:2022-11-18 until:2022-11-19
# russia ukrain war since:2022-11-19 until:2022-11-20
# russia ukrain war since:2022-11-20 until:2022-11-21
# russia ukrain war since:2022-11-21 until:2022-11-22
# russia ukrain war since:2022-11-22 until:2022-11-23
# russia ukrain war since:2022-11-23 until:2022-11-24
# russia ukrain war since:2022-11-24 until:2022-11-25
# russia ukrain war since:2022-11-25 until:2022-11-26
# russia ukrain war since:2022-11-26 until:2022-11-27
# russia ukrain war since:2022-11-27 until:2022-11-28
# russia ukrain war since:2022-11-28 until:2022-11-29
# russia ukrain war since:2022-11-29 until:2022-11-30
# russia ukrain war since:2022-11-30 until:2022-12-01
# russia ukrain war since:2022-12-01 until:2022-12-02
# search_query: inflation
# inflation since:2022-04-01 until:2022-04-02
# inflation since:2022-04-02 until:2022-04-03
# inflation since:2022-04-03 until:2022-04-04
# inflation since:2022-04-04 until:2022-04-05
# inflation since:2022-04-05 until:2022-04-06
# inflation since:2022-04-06 until:2022-04-07
# inflation since:2022-04-07 until:2022-04-08
# inflation since:2022-04-08 until:2022-04-09
# inflation since:2022-04-09 until:2022-04-10
# inflation since:2022-04-10 until:2022-04-11
# inflation since:2022-04-11 until:2022-04-12
# inflation since:2022-04-12 until:2022-04-13
# inflation since:2022-04-13 until:2022-04-14
# inflation since:2022-04-14 until:2022-04-15
# inflation since:2022-04-15 until:2022-04-16
# inflation since:2022-04-16 until:2022-04-17
# inflation since:2022-04-17 until:2022-04-18
# inflation since:2022-04-18 until:2022-04-19
# inflation since:2022-04-19 until:2022-04-20
# inflation since:2022-04-20 until:2022-04-21
# inflation since:2022-04-21 until:2022-04-22
# inflation since:2022-04-22 until:2022-04-23
# inflation since:2022-04-23 until:2022-04-24
# inflation since:2022-04-24 until:2022-04-25
# inflation since:2022-04-25 until:2022-04-26
# inflation since:2022-04-26 until:2022-04-27
# inflation since:2022-04-27 until:2022-04-28
# inflation since:2022-04-28 until:2022-04-29
# inflation since:2022-04-29 until:2022-04-30
# inflation since:2022-04-30 until:2022-05-01
# inflation since:2022-05-01 until:2022-05-02
# inflation since:2022-05-02 until:2022-05-03
# inflation since:2022-05-03 until:2022-05-04
# inflation since:2022-05-04 until:2022-05-05
# inflation since:2022-05-05 until:2022-05-06
# inflation since:2022-05-06 until:2022-05-07
# inflation since:2022-05-07 until:2022-05-08
# inflation since:2022-05-08 until:2022-05-09
# inflation since:2022-05-09 until:2022-05-10
# inflation since:2022-05-10 until:2022-05-11
# inflation since:2022-05-11 until:2022-05-12
# inflation since:2022-05-12 until:2022-05-13
# inflation since:2022-05-13 until:2022-05-14
# inflation since:2022-05-14 until:2022-05-15
# inflation since:2022-05-15 until:2022-05-16
# inflation since:2022-05-16 until:2022-05-17
# inflation since:2022-05-17 until:2022-05-18
# inflation since:2022-05-18 until:2022-05-19
# inflation since:2022-05-19 until:2022-05-20
# inflation since:2022-05-20 until:2022-05-21
# inflation since:2022-05-21 until:2022-05-22
# inflation since:2022-05-22 until:2022-05-23
# inflation since:2022-05-23 until:2022-05-24
# inflation since:2022-05-24 until:2022-05-25
# inflation since:2022-05-25 until:2022-05-26
# inflation since:2022-05-26 until:2022-05-27
# inflation since:2022-05-27 until:2022-05-28
# inflation since:2022-05-28 until:2022-05-29
# inflation since:2022-05-29 until:2022-05-30
# inflation since:2022-05-30 until:2022-05-31
# inflation since:2022-05-31 until:2022-06-01
# inflation since:2022-06-01 until:2022-06-02
# inflation since:2022-06-02 until:2022-06-03
# inflation since:2022-06-03 until:2022-06-04
# inflation since:2022-06-04 until:2022-06-05
# inflation since:2022-06-05 until:2022-06-06
# inflation since:2022-06-06 until:2022-06-07
# inflation since:2022-06-07 until:2022-06-08
# inflation since:2022-06-08 until:2022-06-09
# inflation since:2022-06-09 until:2022-06-10
# inflation since:2022-06-10 until:2022-06-11
# inflation since:2022-06-11 until:2022-06-12
# inflation since:2022-06-12 until:2022-06-13
# inflation since:2022-06-13 until:2022-06-14
# inflation since:2022-06-14 until:2022-06-15
# inflation since:2022-06-15 until:2022-06-16
# inflation since:2022-06-16 until:2022-06-17
# inflation since:2022-06-17 until:2022-06-18
# inflation since:2022-06-18 until:2022-06-19
# inflation since:2022-06-19 until:2022-06-20
# inflation since:2022-06-20 until:2022-06-21
# inflation since:2022-06-21 until:2022-06-22
# inflation since:2022-06-22 until:2022-06-23
# inflation since:2022-06-23 until:2022-06-24
# inflation since:2022-06-24 until:2022-06-25
# inflation since:2022-06-25 until:2022-06-26
# inflation since:2022-06-26 until:2022-06-27
# inflation since:2022-06-27 until:2022-06-28
# inflation since:2022-06-28 until:2022-06-29
# inflation since:2022-06-29 until:2022-06-30
# inflation since:2022-06-30 until:2022-07-01
# inflation since:2022-07-01 until:2022-07-02
# inflation since:2022-07-02 until:2022-07-03
# inflation since:2022-07-03 until:2022-07-04
# inflation since:2022-07-04 until:2022-07-05
# inflation since:2022-07-05 until:2022-07-06
# inflation since:2022-07-06 until:2022-07-07
# inflation since:2022-07-07 until:2022-07-08
# inflation since:2022-07-08 until:2022-07-09
# inflation since:2022-07-09 until:2022-07-10
# inflation since:2022-07-10 until:2022-07-11
# inflation since:2022-07-11 until:2022-07-12
# inflation since:2022-07-12 until:2022-07-13
# inflation since:2022-07-13 until:2022-07-14
# inflation since:2022-07-14 until:2022-07-15
# inflation since:2022-07-15 until:2022-07-16
# inflation since:2022-07-16 until:2022-07-17
# inflation since:2022-07-17 until:2022-07-18
# inflation since:2022-07-18 until:2022-07-19
# inflation since:2022-07-19 until:2022-07-20
# inflation since:2022-07-20 until:2022-07-21
# inflation since:2022-07-21 until:2022-07-22
# inflation since:2022-07-22 until:2022-07-23
# inflation since:2022-07-23 until:2022-07-24
# inflation since:2022-07-24 until:2022-07-25
# inflation since:2022-07-25 until:2022-07-26
# inflation since:2022-07-26 until:2022-07-27
# inflation since:2022-07-27 until:2022-07-28
# inflation since:2022-07-28 until:2022-07-29
# inflation since:2022-07-29 until:2022-07-30
# inflation since:2022-07-30 until:2022-07-31
# inflation since:2022-07-31 until:2022-08-01
# inflation since:2022-08-01 until:2022-08-02
# inflation since:2022-08-02 until:2022-08-03
# inflation since:2022-08-03 until:2022-08-04
# inflation since:2022-08-04 until:2022-08-05
# inflation since:2022-08-05 until:2022-08-06
# inflation since:2022-08-06 until:2022-08-07
# inflation since:2022-08-07 until:2022-08-08
# inflation since:2022-08-08 until:2022-08-09
# inflation since:2022-08-09 until:2022-08-10
# inflation since:2022-08-10 until:2022-08-11
# inflation since:2022-08-11 until:2022-08-12
# inflation since:2022-08-12 until:2022-08-13
# inflation since:2022-08-13 until:2022-08-14
# inflation since:2022-08-14 until:2022-08-15
# inflation since:2022-08-15 until:2022-08-16
# inflation since:2022-08-16 until:2022-08-17
# inflation since:2022-08-17 until:2022-08-18
# inflation since:2022-08-18 until:2022-08-19
# inflation since:2022-08-19 until:2022-08-20
# inflation since:2022-08-20 until:2022-08-21
# inflation since:2022-08-21 until:2022-08-22
# inflation since:2022-08-22 until:2022-08-23
# inflation since:2022-08-23 until:2022-08-24
# inflation since:2022-08-24 until:2022-08-25
# inflation since:2022-08-25 until:2022-08-26
# inflation since:2022-08-26 until:2022-08-27
# inflation since:2022-08-27 until:2022-08-28
# inflation since:2022-08-28 until:2022-08-29
# inflation since:2022-08-29 until:2022-08-30
# inflation since:2022-08-30 until:2022-08-31
# inflation since:2022-08-31 until:2022-09-01
# inflation since:2022-09-01 until:2022-09-02
# inflation since:2022-09-02 until:2022-09-03
# inflation since:2022-09-03 until:2022-09-04
# inflation since:2022-09-04 until:2022-09-05
# inflation since:2022-09-05 until:2022-09-06
# inflation since:2022-09-06 until:2022-09-07
# inflation since:2022-09-07 until:2022-09-08
# inflation since:2022-09-08 until:2022-09-09
# inflation since:2022-09-09 until:2022-09-10
# inflation since:2022-09-10 until:2022-09-11
# inflation since:2022-09-11 until:2022-09-12
# inflation since:2022-09-12 until:2022-09-13
# inflation since:2022-09-13 until:2022-09-14
# inflation since:2022-09-14 until:2022-09-15
# inflation since:2022-09-15 until:2022-09-16
# inflation since:2022-09-16 until:2022-09-17
# inflation since:2022-09-17 until:2022-09-18
# inflation since:2022-09-18 until:2022-09-19
# inflation since:2022-09-19 until:2022-09-20
# inflation since:2022-09-20 until:2022-09-21
# inflation since:2022-09-21 until:2022-09-22
# inflation since:2022-09-22 until:2022-09-23
# inflation since:2022-09-23 until:2022-09-24
# inflation since:2022-09-24 until:2022-09-25
# inflation since:2022-09-25 until:2022-09-26
# inflation since:2022-09-26 until:2022-09-27
# inflation since:2022-09-27 until:2022-09-28
# inflation since:2022-09-28 until:2022-09-29
# inflation since:2022-09-29 until:2022-09-30
# inflation since:2022-09-30 until:2022-10-01
# inflation since:2022-10-01 until:2022-10-02
# inflation since:2022-10-02 until:2022-10-03
# inflation since:2022-10-03 until:2022-10-04
# inflation since:2022-10-04 until:2022-10-05
# inflation since:2022-10-05 until:2022-10-06
# inflation since:2022-10-06 until:2022-10-07
# inflation since:2022-10-07 until:2022-10-08
# inflation since:2022-10-08 until:2022-10-09
# inflation since:2022-10-09 until:2022-10-10
# inflation since:2022-10-10 until:2022-10-11
# inflation since:2022-10-11 until:2022-10-12
# inflation since:2022-10-12 until:2022-10-13
# inflation since:2022-10-13 until:2022-10-14
# inflation since:2022-10-14 until:2022-10-15
# inflation since:2022-10-15 until:2022-10-16
# inflation since:2022-10-16 until:2022-10-17
# inflation since:2022-10-17 until:2022-10-18
# inflation since:2022-10-18 until:2022-10-19
# inflation since:2022-10-19 until:2022-10-20
# inflation since:2022-10-20 until:2022-10-21
# inflation since:2022-10-21 until:2022-10-22
# inflation since:2022-10-22 until:2022-10-23
# inflation since:2022-10-23 until:2022-10-24
# inflation since:2022-10-24 until:2022-10-25
# inflation since:2022-10-25 until:2022-10-26
# inflation since:2022-10-26 until:2022-10-27
# inflation since:2022-10-27 until:2022-10-28
# inflation since:2022-10-28 until:2022-10-29
# inflation since:2022-10-29 until:2022-10-30
# inflation since:2022-10-30 until:2022-10-31
# inflation since:2022-10-31 until:2022-11-01
# inflation since:2022-11-01 until:2022-11-02
# inflation since:2022-11-02 until:2022-11-03
# inflation since:2022-11-03 until:2022-11-04
# inflation since:2022-11-04 until:2022-11-05
# inflation since:2022-11-05 until:2022-11-06
# inflation since:2022-11-06 until:2022-11-07
# inflation since:2022-11-07 until:2022-11-08
# inflation since:2022-11-08 until:2022-11-09
# inflation since:2022-11-09 until:2022-11-10
# inflation since:2022-11-10 until:2022-11-11
# inflation since:2022-11-11 until:2022-11-12
# inflation since:2022-11-12 until:2022-11-13
# inflation since:2022-11-13 until:2022-11-14
# inflation since:2022-11-14 until:2022-11-15
# inflation since:2022-11-15 until:2022-11-16
# inflation since:2022-11-16 until:2022-11-17
# inflation since:2022-11-17 until:2022-11-18
# inflation since:2022-11-18 until:2022-11-19
# inflation since:2022-11-19 until:2022-11-20
# inflation since:2022-11-20 until:2022-11-21
# inflation since:2022-11-21 until:2022-11-22
# inflation since:2022-11-22 until:2022-11-23
# inflation since:2022-11-23 until:2022-11-24
# inflation since:2022-11-24 until:2022-11-25
# inflation since:2022-11-25 until:2022-11-26
# inflation since:2022-11-26 until:2022-11-27
# inflation since:2022-11-27 until:2022-11-28
# inflation since:2022-11-28 until:2022-11-29
# inflation since:2022-11-29 until:2022-11-30
# inflation since:2022-11-30 until:2022-12-01
# inflation since:2022-12-01 until:2022-12-02
# search_query: gas prices
# gas prices since:2022-04-01 until:2022-04-02
# gas prices since:2022-04-02 until:2022-04-03
# gas prices since:2022-04-03 until:2022-04-04
# gas prices since:2022-04-04 until:2022-04-05
# gas prices since:2022-04-05 until:2022-04-06
# gas prices since:2022-04-06 until:2022-04-07
# gas prices since:2022-04-07 until:2022-04-08
# gas prices since:2022-04-08 until:2022-04-09
# gas prices since:2022-04-09 until:2022-04-10
# gas prices since:2022-04-10 until:2022-04-11
# gas prices since:2022-04-11 until:2022-04-12
# gas prices since:2022-04-12 until:2022-04-13
# gas prices since:2022-04-13 until:2022-04-14
# gas prices since:2022-04-14 until:2022-04-15
# gas prices since:2022-04-15 until:2022-04-16
# gas prices since:2022-04-16 until:2022-04-17
# gas prices since:2022-04-17 until:2022-04-18
# gas prices since:2022-04-18 until:2022-04-19
# gas prices since:2022-04-19 until:2022-04-20
# gas prices since:2022-04-20 until:2022-04-21
# gas prices since:2022-04-21 until:2022-04-22
# gas prices since:2022-04-22 until:2022-04-23
# gas prices since:2022-04-23 until:2022-04-24
# gas prices since:2022-04-24 until:2022-04-25
# gas prices since:2022-04-25 until:2022-04-26
# gas prices since:2022-04-26 until:2022-04-27
# gas prices since:2022-04-27 until:2022-04-28
# gas prices since:2022-04-28 until:2022-04-29
# gas prices since:2022-04-29 until:2022-04-30
# gas prices since:2022-04-30 until:2022-05-01
# gas prices since:2022-05-01 until:2022-05-02
# gas prices since:2022-05-02 until:2022-05-03
# gas prices since:2022-05-03 until:2022-05-04
# gas prices since:2022-05-04 until:2022-05-05
# gas prices since:2022-05-05 until:2022-05-06
# gas prices since:2022-05-06 until:2022-05-07
# gas prices since:2022-05-07 until:2022-05-08
# gas prices since:2022-05-08 until:2022-05-09
# gas prices since:2022-05-09 until:2022-05-10
# gas prices since:2022-05-10 until:2022-05-11
# gas prices since:2022-05-11 until:2022-05-12
# gas prices since:2022-05-12 until:2022-05-13
# gas prices since:2022-05-13 until:2022-05-14
# gas prices since:2022-05-14 until:2022-05-15
# gas prices since:2022-05-15 until:2022-05-16
# gas prices since:2022-05-16 until:2022-05-17
# gas prices since:2022-05-17 until:2022-05-18
# gas prices since:2022-05-18 until:2022-05-19
# gas prices since:2022-05-19 until:2022-05-20
# gas prices since:2022-05-20 until:2022-05-21
# gas prices since:2022-05-21 until:2022-05-22
# gas prices since:2022-05-22 until:2022-05-23
# gas prices since:2022-05-23 until:2022-05-24
# gas prices since:2022-05-24 until:2022-05-25
# gas prices since:2022-05-25 until:2022-05-26
# gas prices since:2022-05-26 until:2022-05-27
# gas prices since:2022-05-27 until:2022-05-28
# gas prices since:2022-05-28 until:2022-05-29
# gas prices since:2022-05-29 until:2022-05-30
# gas prices since:2022-05-30 until:2022-05-31
# gas prices since:2022-05-31 until:2022-06-01
# gas prices since:2022-06-01 until:2022-06-02
# gas prices since:2022-06-02 until:2022-06-03
# gas prices since:2022-06-03 until:2022-06-04
# gas prices since:2022-06-04 until:2022-06-05
# gas prices since:2022-06-05 until:2022-06-06
# gas prices since:2022-06-06 until:2022-06-07
# gas prices since:2022-06-07 until:2022-06-08
# gas prices since:2022-06-08 until:2022-06-09
# gas prices since:2022-06-09 until:2022-06-10
# gas prices since:2022-06-10 until:2022-06-11
# gas prices since:2022-06-11 until:2022-06-12
# gas prices since:2022-06-12 until:2022-06-13
# gas prices since:2022-06-13 until:2022-06-14
# gas prices since:2022-06-14 until:2022-06-15
# gas prices since:2022-06-15 until:2022-06-16
# gas prices since:2022-06-16 until:2022-06-17
# gas prices since:2022-06-17 until:2022-06-18
# gas prices since:2022-06-18 until:2022-06-19
# gas prices since:2022-06-19 until:2022-06-20
# gas prices since:2022-06-20 until:2022-06-21
# gas prices since:2022-06-21 until:2022-06-22
# gas prices since:2022-06-22 until:2022-06-23
# gas prices since:2022-06-23 until:2022-06-24
# gas prices since:2022-06-24 until:2022-06-25
# gas prices since:2022-06-25 until:2022-06-26
# gas prices since:2022-06-26 until:2022-06-27
# gas prices since:2022-06-27 until:2022-06-28
# gas prices since:2022-06-28 until:2022-06-29
# gas prices since:2022-06-29 until:2022-06-30
# gas prices since:2022-06-30 until:2022-07-01
# gas prices since:2022-07-01 until:2022-07-02
# gas prices since:2022-07-02 until:2022-07-03
# gas prices since:2022-07-03 until:2022-07-04
# gas prices since:2022-07-04 until:2022-07-05
# gas prices since:2022-07-05 until:2022-07-06
# gas prices since:2022-07-06 until:2022-07-07
# gas prices since:2022-07-07 until:2022-07-08
# gas prices since:2022-07-08 until:2022-07-09
# gas prices since:2022-07-09 until:2022-07-10
# gas prices since:2022-07-10 until:2022-07-11
# gas prices since:2022-07-11 until:2022-07-12
# gas prices since:2022-07-12 until:2022-07-13
# gas prices since:2022-07-13 until:2022-07-14
# gas prices since:2022-07-14 until:2022-07-15
# gas prices since:2022-07-15 until:2022-07-16
# gas prices since:2022-07-16 until:2022-07-17
# gas prices since:2022-07-17 until:2022-07-18
# gas prices since:2022-07-18 until:2022-07-19
# gas prices since:2022-07-19 until:2022-07-20
# gas prices since:2022-07-20 until:2022-07-21
# gas prices since:2022-07-21 until:2022-07-22
# gas prices since:2022-07-22 until:2022-07-23
# gas prices since:2022-07-23 until:2022-07-24
# gas prices since:2022-07-24 until:2022-07-25
# gas prices since:2022-07-25 until:2022-07-26
# gas prices since:2022-07-26 until:2022-07-27
# gas prices since:2022-07-27 until:2022-07-28
# gas prices since:2022-07-28 until:2022-07-29
# gas prices since:2022-07-29 until:2022-07-30
# gas prices since:2022-07-30 until:2022-07-31
# gas prices since:2022-07-31 until:2022-08-01
# gas prices since:2022-08-01 until:2022-08-02
# gas prices since:2022-08-02 until:2022-08-03
# gas prices since:2022-08-03 until:2022-08-04
# gas prices since:2022-08-04 until:2022-08-05
# gas prices since:2022-08-05 until:2022-08-06
# gas prices since:2022-08-06 until:2022-08-07
# gas prices since:2022-08-07 until:2022-08-08
# gas prices since:2022-08-08 until:2022-08-09
# gas prices since:2022-08-09 until:2022-08-10
# gas prices since:2022-08-10 until:2022-08-11
# gas prices since:2022-08-11 until:2022-08-12
# gas prices since:2022-08-12 until:2022-08-13
# gas prices since:2022-08-13 until:2022-08-14
# gas prices since:2022-08-14 until:2022-08-15
# gas prices since:2022-08-15 until:2022-08-16
# gas prices since:2022-08-16 until:2022-08-17
# gas prices since:2022-08-17 until:2022-08-18
# gas prices since:2022-08-18 until:2022-08-19
# gas prices since:2022-08-19 until:2022-08-20
# gas prices since:2022-08-20 until:2022-08-21
# gas prices since:2022-08-21 until:2022-08-22
# gas prices since:2022-08-22 until:2022-08-23
# gas prices since:2022-08-23 until:2022-08-24
# gas prices since:2022-08-24 until:2022-08-25
# gas prices since:2022-08-25 until:2022-08-26
# gas prices since:2022-08-26 until:2022-08-27
# gas prices since:2022-08-27 until:2022-08-28
# gas prices since:2022-08-28 until:2022-08-29
# gas prices since:2022-08-29 until:2022-08-30
# gas prices since:2022-08-30 until:2022-08-31
# gas prices since:2022-08-31 until:2022-09-01
# gas prices since:2022-09-01 until:2022-09-02
# gas prices since:2022-09-02 until:2022-09-03
# gas prices since:2022-09-03 until:2022-09-04
# gas prices since:2022-09-04 until:2022-09-05
# gas prices since:2022-09-05 until:2022-09-06
# gas prices since:2022-09-06 until:2022-09-07
# gas prices since:2022-09-07 until:2022-09-08
# gas prices since:2022-09-08 until:2022-09-09
# gas prices since:2022-09-09 until:2022-09-10
# gas prices since:2022-09-10 until:2022-09-11
# gas prices since:2022-09-11 until:2022-09-12
# gas prices since:2022-09-12 until:2022-09-13
# gas prices since:2022-09-13 until:2022-09-14
# gas prices since:2022-09-14 until:2022-09-15
# gas prices since:2022-09-15 until:2022-09-16
# gas prices since:2022-09-16 until:2022-09-17
# gas prices since:2022-09-17 until:2022-09-18
# gas prices since:2022-09-18 until:2022-09-19
# gas prices since:2022-09-19 until:2022-09-20
# gas prices since:2022-09-20 until:2022-09-21
# gas prices since:2022-09-21 until:2022-09-22
# gas prices since:2022-09-22 until:2022-09-23
# gas prices since:2022-09-23 until:2022-09-24
# gas prices since:2022-09-24 until:2022-09-25
# gas prices since:2022-09-25 until:2022-09-26
# gas prices since:2022-09-26 until:2022-09-27
# gas prices since:2022-09-27 until:2022-09-28
# gas prices since:2022-09-28 until:2022-09-29
# gas prices since:2022-09-29 until:2022-09-30
# gas prices since:2022-09-30 until:2022-10-01
# gas prices since:2022-10-01 until:2022-10-02
# gas prices since:2022-10-02 until:2022-10-03
# gas prices since:2022-10-03 until:2022-10-04
# gas prices since:2022-10-04 until:2022-10-05
# gas prices since:2022-10-05 until:2022-10-06
# gas prices since:2022-10-06 until:2022-10-07
# gas prices since:2022-10-07 until:2022-10-08
# gas prices since:2022-10-08 until:2022-10-09
# gas prices since:2022-10-09 until:2022-10-10
# gas prices since:2022-10-10 until:2022-10-11
# gas prices since:2022-10-11 until:2022-10-12
# gas prices since:2022-10-12 until:2022-10-13
# gas prices since:2022-10-13 until:2022-10-14
# gas prices since:2022-10-14 until:2022-10-15
# gas prices since:2022-10-15 until:2022-10-16
# gas prices since:2022-10-16 until:2022-10-17
# gas prices since:2022-10-17 until:2022-10-18
# gas prices since:2022-10-18 until:2022-10-19
# gas prices since:2022-10-19 until:2022-10-20
# gas prices since:2022-10-20 until:2022-10-21
# gas prices since:2022-10-21 until:2022-10-22
# gas prices since:2022-10-22 until:2022-10-23
# gas prices since:2022-10-23 until:2022-10-24
# gas prices since:2022-10-24 until:2022-10-25
# gas prices since:2022-10-25 until:2022-10-26
# gas prices since:2022-10-26 until:2022-10-27
# gas prices since:2022-10-27 until:2022-10-28
# gas prices since:2022-10-28 until:2022-10-29
# gas prices since:2022-10-29 until:2022-10-30
# gas prices since:2022-10-30 until:2022-10-31
# gas prices since:2022-10-31 until:2022-11-01
# gas prices since:2022-11-01 until:2022-11-02
# gas prices since:2022-11-02 until:2022-11-03
# gas prices since:2022-11-03 until:2022-11-04
# gas prices since:2022-11-04 until:2022-11-05
# gas prices since:2022-11-05 until:2022-11-06
# gas prices since:2022-11-06 until:2022-11-07
# gas prices since:2022-11-07 until:2022-11-08
# gas prices since:2022-11-08 until:2022-11-09
# gas prices since:2022-11-09 until:2022-11-10
# gas prices since:2022-11-10 until:2022-11-11
# gas prices since:2022-11-11 until:2022-11-12
# gas prices since:2022-11-12 until:2022-11-13
# gas prices since:2022-11-13 until:2022-11-14
# gas prices since:2022-11-14 until:2022-11-15
# gas prices since:2022-11-15 until:2022-11-16
# gas prices since:2022-11-16 until:2022-11-17
# gas prices since:2022-11-17 until:2022-11-18
# gas prices since:2022-11-18 until:2022-11-19
# gas prices since:2022-11-19 until:2022-11-20
# gas prices since:2022-11-20 until:2022-11-21
# gas prices since:2022-11-21 until:2022-11-22
# gas prices since:2022-11-22 until:2022-11-23
# gas prices since:2022-11-23 until:2022-11-24
# gas prices since:2022-11-24 until:2022-11-25
# gas prices since:2022-11-25 until:2022-11-26
# gas prices since:2022-11-26 until:2022-11-27
# gas prices since:2022-11-27 until:2022-11-28
# gas prices since:2022-11-28 until:2022-11-29
# gas prices since:2022-11-29 until:2022-11-30
# gas prices since:2022-11-30 until:2022-12-01
# gas prices since:2022-12-01 until:2022-12-02
#
#
# TOTAL TIME TAKEN 40.266666666666666 minutes

# %%
print(twitter_data.shape)
twitter_data.head()
# Out:
# (16720, 14)
#          date                                              tweet lang  \
# 0  2022-04-01  DON'T let the life of this earth delude you.\n...   en
# 1  2022-04-01  @louvelune @KyivIndependent The communist Sovi...   en
# 2  2022-04-01  NEW BLOG:  US Crises... Domestic Challenges &a...   en
# 3  2022-04-01  جایگاه ورزش در دنیا می تونه ترویج گفتمان صلح ب...   fa
# 4  2022-04-01  @WeHearPodcast @HarryPotterMAGE How about Ur o...   en
#
#   retweetCount likeCount replyCount         username user_followersCount  \
# 0            0         1          0      ciira_cyrus               51358
# 1            0         0          1      CatManDoo18                 964
# 2            0         0          0   IanRMackintosh               12067
# 3            0         0          0  neshan_eftekhar                 237
# 4            0         0          0      swithtalker                 906
#
#   user_friendsCount verifiedStatus  \
# 0             49095          False
# 1               229          False
# 2              9248          False
# 3               347          False
# 4              4761          False
#
#                                            tweet_url  \
# 0  https://twitter.com/ciira_cyrus/status/1510024...
# 1  https://twitter.com/CatManDoo18/status/1510008...
# 2  https://twitter.com/IanRMackintosh/status/1509...
# 3  https://twitter.com/neshan_eftekhar/status/150...
# 4  https://twitter.com/swithtalker/status/1509954...
#
#                                              hastags chr_count  \
# 0                            [MessageOfResurrection]       288
# 1                                  [RussiaUkrainWar]       309
# 2  [Coronavirus, learn, pandemic, worldwvents, ru...       173
# 3  [جام_جهانی2022, جنگ_روسیه_اکراین, russia_ukrai...       226
# 4                                               None       281
#
#                topic
# 0  russia ukrain war
# 1  russia ukrain war
# 2  russia ukrain war
# 3  russia ukrain war
# 4  russia ukrain war

# %% [markdown]
# ## Output

# %%
def read_copy(path="."):
    for f in os.listdir(path):
        if f.endswith('local.csv'):
            df = pd.read_csv(f, lineterminator='\n')
            df.hastags = df.hastags.apply(lambda x: literal_eval(x) if str(x) not in ['none', 'nan', 'np.nan', 'null', ''] else None)
            return df

# %%
df = read_copy(root_dir)
df
# Out:
#              date                                              tweet lang  \
# 0      2022-04-01  DON'T let the life of this earth delude you.\n...   en
# 1      2022-04-01  @louvelune @KyivIndependent The communist Sovi...   en
# 2      2022-04-01  NEW BLOG:  US Crises... Domestic Challenges &a...   en
# 3      2022-04-01  جایگاه ورزش در دنیا می تونه ترویج گفتمان صلح ب...   fa
# 4      2022-04-01  @WeHearPodcast @HarryPotterMAGE How about Ur o...   en
# ...           ...                                                ...  ...
# 16715  2022-12-01  Current Gas prices post-black Friday+Cyber Mon...   en
# 16716  2022-12-01  @RonnyJacksonTX Do they have a plan for inflat...   en
# 16717  2022-12-01  @Jason27614314 @KrissyLUnited @TierraHenson @S...   en
# 16718  2022-12-01  @dbongino Gas prices are down, stock market is...   en
# 16719  2022-12-01  U.S. gas prices fall to pre–Ukraine invasion l...   en
#
#        retweetCount  likeCount  replyCount         username  \
# 0                 0          1           0      ciira_cyrus
# 1                 0          0           1      CatManDoo18
# 2                 0          0           0   IanRMackintosh
# 3                 0          0           0  neshan_eftekhar
# 4                 0          0           0      swithtalker
# ...             ...        ...         ...              ...
# 16715             0          1           0        Aru762mmR
# 16716             0          0           0    CoachPete2323
# 16717             1          3           2  johnnysunset287
# 16718             0          5           4        glr4cblaw
# 16719             0          0           0    65rosesauthor
#
#        user_followersCount  user_friendsCount  verifiedStatus  \
# 0                    51358              49095           False
# 1                      964                229           False
# 2                    12067               9248           False
# 3                      237                347           False
# 4                      906               4761           False
# ...                    ...                ...             ...
# 16715                  703               1368           False
# 16716                 1045               3752           False
# 16717                 1539               4993           False
# 16718                 2046               3716           False
# 16719                 1021               4386           False
#
#                                                tweet_url  \
# 0      https://twitter.com/ciira_cyrus/status/1510024...
# 1      https://twitter.com/CatManDoo18/status/1510008...
# 2      https://twitter.com/IanRMackintosh/status/1509...
# 3      https://twitter.com/neshan_eftekhar/status/150...
# 4      https://twitter.com/swithtalker/status/1509954...
# ...                                                  ...
# 16715  https://twitter.com/Aru762mmR/status/159846436...
# 16716  https://twitter.com/CoachPete2323/status/15984...
# 16717  https://twitter.com/johnnysunset287/status/159...
# 16718  https://twitter.com/glr4cblaw/status/159846416...
# 16719  https://twitter.com/65rosesauthor/status/15984...
#
#                                                  hastags  chr_count  \
# 0                                [MessageOfResurrection]        288
# 1                                      [RussiaUkrainWar]        309
# 2      [Coronavirus, learn, pandemic, worldwvents, ru...        173
# 3      [جام_جهانی2022, جنگ_روسیه_اکراین, russia_ukrai...        226
# 4                                                   None        281
# ...                                                  ...        ...
# 16715                                               None        147
# 16716                                               None         89
# 16717              [PrayTogether, peace, Ukraine, Trump]       1002
# 16718                                               None        290
# 16719                                               None        121
#
#                    topic
# 0      russia ukrain war
# 1      russia ukrain war
# 2      russia ukrain war
# 3      russia ukrain war
# 4      russia ukrain war
# ...                  ...
# 16715         gas prices
# 16716         gas prices
# 16717         gas prices
# 16718         gas prices
# 16719         gas prices
#
# [16720 rows x 14 columns]

# %% [markdown]
# ### Citations

# %% [markdown]
# Credits to the awesome social media mining tool SNScrape (https://github.com/JustAnotherArchivist/snscrape)

# %% [markdown]
# ---
