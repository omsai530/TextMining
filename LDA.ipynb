# %%
# !pip install tweet-preprocessor
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tweet-preprocessor
#   Downloading tweet_preprocessor-0.6.0-py3-none-any.whl (27 kB)
# Installing collected packages: tweet-preprocessor
# Successfully installed tweet-preprocessor-0.6.0

# %%
import preprocessor as p
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('Final (1).csv')

# %%
df.head(5)
# Out:
#                topic                                              tweet
# 0  russia ukrain war  dont let the life this earth delude you becaus...
# 1  russia ukrain war  the communist soviet union ended december comm...
# 2  russia ukrain war  new blog crises domestic challenges amp europe...
# 3  russia ukrain war  how about own people doing what brillian idea ...
# 4  russia ukrain war  day ukrain war aginst russia europe faces gas ...

# %%
new_tweets=[]
for i in df['tweet']:
  new_tweets.append(p.clean(str(i)))

# %%
import nltk
from nltk import word_tokenize, FreqDist
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
nltk.download
nltk.download('wordnet')
nltk.download('stopwords')
from nltk.tokenize import TweetTokenizer
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import nltk
nltk.download('omw-1.4')
stop_words = set(stopwords.words('english'))
w_tokenizer = TweetTokenizer()
for i in range(0,len(new_tweets)):
  w=w_tokenizer.tokenize(str(new_tweets[i]))
  new_tweets[i]=w
  new_tweets[i] = [item for item in new_tweets[i] if item not in stop_words]
# Out:
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
from nltk.stem.porter import PorterStemmer
l=new_tweets

# %%
import gensim
from gensim import corpora
dictionary = corpora.Dictionary(l)
doc_term_matrix = [dictionary.doc2bow(doc) for doc in l]

# %%
Lda = gensim.models.ldamodel.LdaModel
ldamodel = Lda(doc_term_matrix, num_topics=7, id2word = dictionary, passes=10)

# %%
#Topic Table
print(ldamodel.print_topics(num_topics=7, num_words=10))
# Out:
# [(0, '0.017*"gop" + 0.015*"taxes" + 0.015*"inflation" + 0.013*"higher" + 0.006*"drop" + 0.006*"families" + 0.006*"amp" + 0.005*"security" + 0.005*"increasing" + 0.005*"natural"'), (1, '0.035*"inflation" + 0.019*"amp" + 0.011*"republicans" + 0.011*"crime" + 0.011*"democrats" + 0.010*"biden" + 0.010*"vote" + 0.008*"would" + 0.007*"border" + 0.007*"people"'), (2, '0.049*"inflation" + 0.010*"price" + 0.009*"rates" + 0.008*"tax" + 0.007*"act" + 0.007*"reduction" + 0.006*"cost" + 0.006*"fed" + 0.006*"interest" + 0.005*"current"'), (3, '0.071*"inflation" + 0.011*"recession" + 0.010*"supply" + 0.010*"higher" + 0.009*"market" + 0.008*"economy" + 0.007*"stock" + 0.006*"global" + 0.006*"rate" + 0.006*"chain"'), (4, '0.019*"gouging" + 0.016*"gasprices" + 0.009*"report" + 0.008*"news" + 0.006*"tank" + 0.005*"special" + 0.005*"liberal" + 0.005*"tonight" + 0.004*"new" + 0.004*"show"'), (5, '0.113*"gas" + 0.112*"prices" + 0.021*"high" + 0.015*"oil" + 0.015*"biden" + 0.009*"inflation" + 0.008*"going" + 0.007*"like" + 0.006*"food" + 0.006*"lower"'), (6, '0.078*"war" + 0.062*"russia" + 0.040*"ukrain" + 0.040*"ukraine" + 0.012*"russian" + 0.010*"people" + 0.010*"nato" + 0.009*"military" + 0.008*"help" + 0.008*"putin"')]

# %%
import pickle
with open("model.pkl","wb") as handle:
  pickle.dump(ldamodel,handle)

# %%
# !pip install pyLDAvis

# %%
import pyLDAvis.gensim_models as gensimvis
import pickle 
import pyLDAvis

# Visualize the topics
pyLDAvis.enable_notebook()

LDAvis_prepared = gensimvis.prepare(ldamodel, doc_term_matrix, dictionary)
with open("lda_visualise.pkl", 'wb') as f:
  pickle.dump(LDAvis_prepared, f)


with open("lda_visualise.pkl", 'rb') as f:
    LDAvis_prepared = pickle.load(f)

pyLDAvis.save_html(LDAvis_prepared, 'ldavis_tuned.html')

LDAvis_prepared
# Out:
# /usr/local/lib/python3.9/dist-packages/pyLDAvis/_prepare.py:243: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   default_term_info = default_term_info.sort_values(
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 5      0.227070 -0.127774       1        1  31.552464
# 1      0.157672 -0.079676       2        1  20.042665
# 2      0.102129  0.074470       3        1  13.250449
# 3      0.036659  0.156307       4        1  11.665049
# 6     -0.257924 -0.220910       5        1  10.872489
# 0     -0.030965  0.086527       6        1   8.201225
# 4     -0.234641  0.111055       7        1   4.415660, topic_info=             Term         Freq        Total Category  logprob  loglift
# 78            gas  9013.000000  9013.000000  Default  30.0000  30.0000
# 1339       prices  8956.000000  8956.000000  Default  29.0000  29.0000
# 19            war  2134.000000  2134.000000  Default  28.0000  28.0000
# 15         russia  1685.000000  1685.000000  Default  27.0000  27.0000
# 91      inflation  6508.000000  6508.000000  Default  26.0000  26.0000
# ...           ...          ...          ...      ...      ...      ...
# 939         check    39.554153   118.294662   Topic7  -5.6355   2.0245
# 14639  outrageous    28.288257    48.386532   Topic7  -5.9708   2.5832
# 2972      address    27.353271    44.917729   Topic7  -6.0044   2.6240
# 52            new    47.174605   418.983242   Topic7  -5.4594   0.9360
# 301         state    36.254493   211.530740   Topic7  -5.7226   1.3562
#
# [386 rows x 6 columns], token_table=       Topic      Freq      Term
# term
# 11766      4  0.978863       aaa
# 3294       2  0.939933  abortion
# 3294       6  0.059157  abortion
# 1259       2  0.153232       act
# 1259       3  0.840906       act
# ...      ...       ...       ...
# 1343       4  0.269414     years
# 1343       6  0.101582     years
# 2498       1  0.320022      zero
# 2498       2  0.073851      zero
# 2498       6  0.603118      zero
#
# [640 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[6, 2, 3, 4, 7, 1, 5])
